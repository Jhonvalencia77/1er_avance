# %%
import pandas as pd
import matplotlib.pyplot as mplt
import seaborn as sbn

# %%
serie_o = pd.read_csv("/home/jonathan/tesis/1er_avance/1erPeriodo_d.csv", sep=',',index_col=0, parse_dates=True)
serie_o.shape
# Out:
# (744, 2844)

# %%
serie_o.head(10)
# Out:
#                      01001_AM    01002  01010_AM  01031_AM     01036  \
# ds
# 2020-02-14 00:00:00   294.283  229.887   133.467   121.669   222.513
# 2020-02-14 01:00:00   227.573  175.788   114.862   155.036   226.210
# 2020-02-14 02:00:00   208.690  115.892   109.916   148.763   182.056
# 2020-02-14 03:00:00   187.762  178.151    86.075   140.993   267.130
# 2020-02-14 04:00:00   419.289  304.075   184.966   322.335   375.552
# 2020-02-14 05:00:00   645.611  827.692   346.857   500.088   954.249
# 2020-02-14 06:00:00   760.749  549.352   564.544   945.635   859.330
# 2020-02-14 07:00:00   941.062  941.563   345.031  1369.515  1518.975
# 2020-02-14 08:00:00  1218.227  809.971   309.681  1206.881  1320.875
# 2020-02-14 09:00:00   796.346  887.051   463.349  1443.238  1073.020
#
#                      01043_AM  01047_AM    01051  01058_AM   0105901  ...  \
# ds                                                                    ...
# ...

# %%
serie_o.tail(10)
# Out:
#                      01001_AM    01002  01010_AM  01031_AM    01036  01043_AM  \
# ds
# 2020-03-15 14:00:00   587.652  350.899   244.487   452.626  317.563   219.519
# 2020-03-15 15:00:00   505.842  322.518   285.068   243.184  441.132   249.294
# 2020-03-15 16:00:00   448.799  282.862   153.071   296.021  282.621   173.236
# 2020-03-15 17:00:00   468.077  389.557   313.408   253.450  392.646   196.809
# 2020-03-15 18:00:00   461.323  334.879   209.239   348.614  395.685   302.543
# 2020-03-15 19:00:00   487.414  481.273   220.379   260.224  492.808   301.701
# 2020-03-15 20:00:00   412.404  369.702   159.067   278.445  347.754   214.190
# 2020-03-15 21:00:00   558.034  346.334   263.269   243.788  298.653   201.792
# 2020-03-15 22:00:00   422.492  230.095   143.177   185.258  202.287   257.542
# 2020-03-15 23:00:00   286.863  121.991    31.453   145.106  123.135   113.047
#
#                      01047_AM    01051  01058_AM  0105901  ...  5200104  \
# ...

# %%
sbn.set(rc={'figure.figsize':(10,5)})
serie_o['01001_AM'].plot(linewidth=0.5)
# Out:
# <AxesSubplot:xlabel='ds'>

# %%
graf_colums = ['01001_AM', '01002', '01010_AM']
ejes = serie_o[graf_colums].plot(marker='.', alpha=0.5,
        linestyle='None', figsize=(10,10),subplots=True)
for eje in ejes:
    eje.set_ylabel('Número de Viajes')

# %%
eje = serie_o.loc['2020-02':'2020-03', '01001_AM'].plot(marker='o', linestyle='-')
eje.set_ylabel('Viajes en Periodo - Normalidad')
# Out:
# Text(0, 0.5, 'Viajes en Periodo - Normalidad')
